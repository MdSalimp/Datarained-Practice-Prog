# %%
import pandas as pd

# %%
df=pd.read_csv("empl.csv")

# %%
print(df)
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df=pd.read_csv('empl.csv',index_col=['SNo'])
print(df)
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
import numpy as np
df=pd.read_csv('empl.csv',dtype={'salary':np.float64})
print(df.dtypes)
df
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# ...

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Salary'].plot()
# Out:
# <AxesSubplot:xlabel='SNo'>

# %%
df1=pd.DataFrame(data=df)

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.loc[:,'Salary']
# Out:
# SNo
# 1     20000.0
# 2      3900.0
# 3      8000.0
# 4     66672.0
# 5         NaN
# 6     30007.0
# 7      8300.0
# 8     54666.0
# 9     67666.0
# 11     8888.0
# 12    66672.0
# 13    34344.0
# 14    30007.0
# 15     8300.0
# 16    54666.0
# 17    67666.0
# 18     8888.0
# 19        NaN
# 20    34432.0
# 21    34534.0
# 22    33451.0
# 23        NaN
# Name: Salary, dtype: float64

# %%
df1.loc[:,'Salary']
# Out:
# SNo
# 1     20000.0
# 2      3900.0
# 3      8000.0
# 4     66672.0
# 5         NaN
# 6     30007.0
# 7      8300.0
# 8     54666.0
# 9     67666.0
# 11     8888.0
# 12    66672.0
# 13    34344.0
# 14    30007.0
# 15     8300.0
# 16    54666.0
# 17    67666.0
# 18     8888.0
# 19        NaN
# 20    34432.0
# 21    34534.0
# 22    33451.0
# 23        NaN
# Name: Salary, dtype: float64

# %%
df1.iloc[:,2:3]
# Out:
#           City
# SNo
# 1      Toronto
# 2      Edmonto
# 3      Toronto
# 4     HongKong
# 5          NaN
# 6     HongKong
# 7      BayArea
# 8    Hyderabad
# 9      newyork
# 11     newyork
# 12    HongKong
# 13         NaN
# 14    HongKong
# 15         NaN
# 16   Hyderabad
# 17     newyork
# 18     newyork
# 19     Edmonto
# 20       Congo
# 21      Angola
# 22     Finland
# 23      London

# %%
df1.loc[-1:2]
# Out:
#     Name   Age     City Country   Salary
# SNo
# 1    Tom  28.0  Toronto  Canada  20000.0
# 2    Lee  31.0  Edmonto  Canada   3900.0

# %%
df1.count()
# Out:
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %%
df1['Name'].nunique()
# Out:
# 14

# %%
df1['Country'].unique()
# Out:
# array(['Canada', 'Asia', 'America', 'Africa', 'Europe'], dtype=object)

# %%
df1['Country'].nunique()
# Out:
# 5

# %%
df1['City'].unique()
# Out:
# array(['Toronto', 'Edmonto', 'HongKong', nan, 'BayArea', 'Hyderabad',
#        'newyork', 'Congo', 'Angola', 'Finland', 'London'], dtype=object)

# %%
df1['City'].nunique()
# Out:
# 10

# %%
print(df1['Name'].describe())
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %%
df2=df1.drop([14,15,16,17],axis=0)
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df2=df1.drop('Name',axis=1)
df2
# Out:
#     SNo   Age       City  Country   Salary
# 0     1  28.0    Toronto   Canada  20000.0
# 1     2  31.0    Edmonto   Canada   3900.0
# 2     3  34.0    Toronto   Canada   8000.0
# 3     4  26.0   HongKong     Asia  66672.0
# 4     5  30.0        NaN  America      NaN
# 5     6   NaN   HongKong     Asia  30007.0
# 6     7  43.0    BayArea  America   8300.0
# 7     8  38.0  Hyderabad     Asia  54666.0
# 8     9  50.0    newyork  America  67666.0
# 9    11   NaN    newyork  America   8888.0
# 10   12  26.0   HongKong     Asia  66672.0
# 11   13  30.0        NaN  America  34344.0
# 12   14  22.0   HongKong     Asia  30007.0
# 13   15  43.0        NaN  America   8300.0
# 14   16  38.0  Hyderabad     Asia  54666.0
# 15   17   NaN    newyork  America  67666.0
# 16   18  27.0    newyork  America   8888.0
# 17   19  31.0    Edmonto   Canada      NaN
# 18   20  34.0      Congo   Africa  34432.0
# 19   21  32.0     Angola   Africa  34534.0
# 20   22  26.0    Finland   Europe  33451.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.add([14,15,16,17],axis=0)
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9012/234982368.py in <module>
# ----> 1 df1.add([14,15,16,17],axis=0)
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     431
#     432         other = maybe_prepare_scalar_for_op(other, self.shape)
# --> 433         self, other = align_method_FRAME(self, other, axis, flex=True, level=level)
#     434
#     435         if isinstance(other, ABCDataFrame):
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     279             )
#     280         # GH17901
# --> 281         right = to_series(right)
#     282
#     283     if flex is not None and isinstance(right, ABCDataFrame):
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in to_series(right)
# ...

# %%
df1.describe()
# Out:
#              Age        Salary
# count  16.000000     15.000000
# mean   32.062500  32028.000000
# std     6.697947  22918.537684
# min    26.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    30.500000  33451.000000
# 75%    34.000000  44600.000000
# max    50.000000  67666.000000

# %%
df1.describe(include='all')
# Out:
#        Name        Age      City  Country        Salary
# count    22  19.000000        19       22     19.000000
# unique   14        NaN        10        5           NaN
# top     Lee        NaN  HongKong  America           NaN
# freq      2        NaN         4        8           NaN
# mean    NaN  32.421053       NaN      NaN  33739.947368
# std     NaN   7.174924       NaN      NaN  23151.188084
# min     NaN  22.000000       NaN      NaN   3900.000000
# 25%     NaN  27.000000       NaN      NaN   8888.000000
# 50%     NaN  31.000000       NaN      NaN  33451.000000
# 75%     NaN  36.000000       NaN      NaN  54666.000000
# max     NaN  50.000000       NaN      NaN  67666.000000

# %%
import pandas as pd
df=pd.read_csv("hrdata.csv")
print(df)
# Out:
#   Name HireDate  Salary  sickday
# 0   gr   1/3/15  500.00       10
# 1   jn   2/6/15  300.11        8
# 2   jn  21/7/15  320.22        5
# 3   te  12/3/15  360.12        4
# 4  teg  16/4/15  410.18        9
# 5  mec   4/8/18  330.19        4

# %%
df=pd.read_csv('hrdata.csv',index_col='Name',parse_dates=['HireDate'])
print(df)
# Out:
#        HireDate  Salary  sickday
# Name
# gr   2015-01-03  500.00       10
# jn   2015-02-06  300.11        8
# jn   2015-07-21  320.22        5
# te   2015-12-03  360.12        4
# teg  2015-04-16  410.18        9
# mec  2018-04-08  330.19        4

# %%
print(type(df['HireDate'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=pd.read_csv('hrdata.csv',index_col='Name',parse_dates=['HireDate'])
print(df)
# Out:
#        HireDate  Salary  sickday
# Name
# gr   2015-01-03  500.00       10
# jn   2015-02-06  300.11        8
# jn   2015-07-21  320.22        5
# te   2015-12-03  360.12        4
# teg  2015-04-16  410.18        9
# mec  2018-04-08  330.19        4

# %%
print(type(df['HireDate'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(type(df['HireDate'][2]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=pd.read_csv('hrdata.csv',index_col='Employee',parse_dates=['Hired'],header=0,
              names=['Employee','Hired','Salary','sick'])
print(df)
# Out:
#               Hired  Salary  sick
# Employee
# gr       2015-01-03  500.00    10
# jn       2015-02-06  300.11     8
# jn       2015-07-21  320.22     5
# te       2015-12-03  360.12     4
# teg      2015-04-16  410.18     9
# mec      2018-04-08  330.19     4

# %%
df
df.to_csv('hrdata_modified.csv')

# %%
dfh=pd.read_csv('hrdata_modified.csv')
dfh
# Out:
#   Name    HireDate  Salary  sickday
# 0   gr  2015-01-03  500.00       10
# 1   jn  2015-02-06  300.11        8
# 2   jn  2015-07-21  320.22        5
# 3   te  2015-12-03  360.12        4
# 4  teg  2015-04-16  410.18        9
# 5  mec  2018-04-08  330.19        4

# %%
dfh['Salary'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
dfh['Salary'].min()
# Out:
# 300.11

# %%
df=pd.read_csv("hrdata.csv")
print(df)
# Out:
#   Name HireDate  Salary  sickday
# 0   gr   1/3/15  500.00       10
# 1   jn   2/6/15  300.11        8
# 2   jn  21/7/15  320.22        5
# 3   te  12/3/15  360.12        4
# 4  teg  16/4/15  410.18        9
# 5  mec   4/8/18  330.19        4

# %%
df=pd.DataFrame(data=df)
df
df.iloc[:,1:3]
# Out:
#   HireDate  Salary
# 0   1/3/15  500.00
# 1   2/6/15  300.11
# 2  21/7/15  320.22
# 3  12/3/15  360.12
# 4  16/4/15  410.18
# 5   4/8/18  330.19

# %%
df.loc[:,['Name',"Salary"]]
# Out:
#   Name  Salary
# 0   gr  500.00
# 1   jn  300.11
# 2   jn  320.22
# 3   te  360.12
# 4  teg  410.18
# 5  mec  330.19

# %%
df.loc[:,'Salary']
# Out:
# 0    500.00
# 1    300.11
# 2    320.22
# 3    360.12
# 4    410.18
# 5    330.19
# Name: Salary, dtype: float64

# %%
df=pd.DataFrame(data=df)
df
df.iloc[:,1:3]
# Out:
#   HireDate  Salary
# 0   1/3/15  500.00
# 1   2/6/15  300.11
# 2  21/7/15  320.22
# 3  12/3/15  360.12
# 4  16/4/15  410.18
# 5   4/8/18  330.19

# %%
df.iloc[:,0:4]
# Out:
#   Name HireDate  Salary  sickday
# 0   gr   1/3/15  500.00       10
# 1   jn   2/6/15  300.11        8
# 2   jn  21/7/15  320.22        5
# 3   te  12/3/15  360.12        4
# 4  teg  16/4/15  410.18        9
# 5  mec   4/8/18  330.19        4

# %%
df.iloc[1:4,-1]
# Out:
# 1    8
# 2    5
# 3    4
# Name: sickday, dtype: int64

# %%
df.count
# Out:
# <bound method DataFrame.count of   Name HireDate  Salary  sickday
# 0   gr   1/3/15  500.00       10
# 1   jn   2/6/15  300.11        8
# 2   jn  21/7/15  320.22        5
# 3   te  12/3/15  360.12        4
# 4  teg  16/4/15  410.18        9
# 5  mec   4/8/18  330.19        4>

# %%
df1=pd.read_csv("empl.csv")

# %%
df1['Name'].count()
# Out:
# 22

# %%
df['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['Canada', 'Asia', 'America', 'Africa', 'Europe'], dtype=object)

# %%
df['Country'].nunique()
# Out:
# 5

# %%
df['City'].unique()
# Out:
# array(['Toronto', 'Edmonto', 'HongKong', nan, 'BayArea', 'Hyderabad',
#        'newyork', 'Congo', 'Angola', 'Finland', 'London'], dtype=object)

# %%
df['City'].nunique()
# Out:
# 10

# %%
print(df['Name'].describe())
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
import requests

# %%
response=requests.get("https://en.wikipedia.org/wiki/Data_science")

# %%
response.status_code
# Out:
# 200

# %%
response=requests.get("https://en.wikipedia.org/wiki/Data_science_does_not_exist")

# %%
response.status_code
# Out:
# 404

# %%
df.describe()
# Out:
#            Salary    sickday
# count    6.000000   6.000000
# mean   370.136667   6.666667
# std     74.242079   2.658320
# min    300.110000   4.000000
# 25%    322.712500   4.250000
# 50%    345.155000   6.500000
# 75%    397.665000   8.750000
# max    500.000000  10.000000

# %%
df.describe(include='all')
# Out:
#               SNo Name        Age      City  Country        Salary
# count   22.000000   22  19.000000        19       22     19.000000
# unique        NaN   14        NaN        10        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    12.090909  NaN  32.421053       NaN      NaN  33739.947368
# std      6.927578  NaN   7.174924       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.250000  NaN  27.000000       NaN      NaN   8888.000000
# 50%     12.500000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.750000  NaN  36.000000       NaN      NaN  54666.000000
# max     23.000000  NaN  50.000000       NaN      NaN  67666.000000

# %%
df.columns
# Out:
# Index(['SNo', 'Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %%
df2=df1.drop([14,15,16,17],axis=0)
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0
# ...

# %%
df2=df1.drop([14,15,16,17])

# %%
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0
# ...

# %%
df2=df1.drop([1,2,3],inplace=True,axis=0)

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 17   19     Lee  31.0    Edmonto   Canada      NaN
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# ...

# %%
df3=df1.drop('Name',axis=1)
df3
# Out:
#     SNo   Age       City  Country   Salary
# 0     1  28.0    Toronto   Canada  20000.0
# 4     5  30.0        NaN  America      NaN
# 5     6   NaN   HongKong     Asia  30007.0
# 6     7  43.0    BayArea  America   8300.0
# 7     8  38.0  Hyderabad     Asia  54666.0
# 8     9  50.0    newyork  America  67666.0
# 9    11   NaN    newyork  America   8888.0
# 10   12  26.0   HongKong     Asia  66672.0
# 11   13  30.0        NaN  America  34344.0
# 12   14  22.0   HongKong     Asia  30007.0
# 13   15  43.0        NaN  America   8300.0
# 14   16  38.0  Hyderabad     Asia  54666.0
# 15   17   NaN    newyork  America  67666.0
# 16   18  27.0    newyork  America   8888.0
# 17   19  31.0    Edmonto   Canada      NaN
# 18   20  34.0      Congo   Africa  34432.0
# 19   21  32.0     Angola   Africa  34534.0
# 20   22  26.0    Finland   Europe  33451.0
# 21   23  27.0     London   Europe      NaN

# %%
df1.drop(['Age','Salary'],axis=1,inplace=True)
df1
# Out:
#     SNo    Name       City  Country
# 0     1     Tom    Toronto   Canada
# 4     5   kamal        NaN  America
# 5     6    Geet   HongKong     Asia
# 6     7  Steven    BayArea  America
# 7     8     Ram  Hyderabad     Asia
# 8     9    hari    newyork  America
# 9    11    yami    newyork  America
# 10   12    Anik   HongKong     Asia
# 11   13   kamal        NaN  America
# 12   14    Geet   HongKong     Asia
# 13   15  Steven        NaN  America
# 14   16     Ram  Hyderabad     Asia
# 15   17    hari    newyork  America
# 16   18    yami    newyork  America
# 17   19     Lee    Edmonto   Canada
# 18   20  Andrew      Congo   Africa
# 19   21   soham     Angola   Africa
# 20   22    Grig    Finland   Europe
# 21   23   Kiara     London   Europe

# %% [markdown]
# # pandas date time functions

# %%
import pandas as pd
df=pd.read_csv('hrdata.csv')
df
# Out:
#   Name HireDate  Salary  sickday
# 0   gr   1/3/15  500.00       10
# 1   jn   2/6/15  300.11        8
# 2   jn  21/7/15  320.22        5
# 3   te  12/3/15  360.12        4
# 4  teg  16/4/15  410.18        9
# 5  mec   4/8/18  330.19        4

# %%
d=pd.to_datetime({'year':[2015],'month':[2],'day':[4]})
d
# Out:
# 0   2015-02-04
# dtype: datetime64[ns]

# %%
df['HireDate']=pd.to_datetime(df['HireDate'])
df
# Out:
#   Name   HireDate  Salary  sickday
# 0   gr 2015-01-03  500.00       10
# 1   jn 2015-02-06  300.11        8
# 2   jn 2015-07-21  320.22        5
# 3   te 2015-12-03  360.12        4
# 4  teg 2015-04-16  410.18        9
# 5  mec 2018-04-08  330.19        4

# %%
daterange=pd.date_range(start='1/1/2020',end='5/1/2020',freq='D')
daterange
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25',
#                '2020-04-26', '2020-04-27', '2020-04-28', '2020-04-29',
#                '2020-04-30', '2020-05-01'],
#               dtype='datetime64[ns]', length=122, freq='D')

# %%
daterange=pd.date_range(start='1/1/2020',end='5/1/2020',freq='M')
daterange
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30'], dtype='datetime64[ns]', freq='M')

# %%
import datetime
dt=datetime.datetime.now()
print(dt)
# Out:
# 2022-05-20 17:19:31.782830

# %%
print(dt+pd.to_timedelta(10,unit='D'))
# Out:
# 2022-05-30 17:19:31.782830

# %%
df['Day']=df['HireDate'].dt.day
df['Month']=df['HireDate'].dt.month
df['Year']=df['HireDate'].dt.year
print(df)
# Out:
#   Name   HireDate  Salary  sickday  Day  Month  Year
# 0   gr 2015-01-03  500.00       10    3      1  2015
# 1   jn 2015-02-06  300.11        8    6      2  2015
# 2   jn 2015-07-21  320.22        5   21      7  2015
# 3   te 2015-12-03  360.12        4    3     12  2015
# 4  teg 2015-04-16  410.18        9   16      4  2015
# 5  mec 2018-04-08  330.19        4    8      4  2018

# %% [markdown]
# # pandas as sql

# %%
import pandas as pd

# %%
df=pd.read_csv("empl.csv")

# %%
print(df)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1=pd.DataFrame(data=df,columns=["Name"])
df1
# Out:
#       Name
# 0      Tom
# 1      Lee
# 2     Dave
# 3     Anik
# 4    kamal
# 5     Geet
# 6   Steven
# 7      Ram
# 8     hari
# 9     yami
# 10    Anik
# 11   kamal
# 12    Geet
# 13  Steven
# 14     Ram
# 15    hari
# 16    yami
# 17     Lee
# 18  Andrew
# 19   soham
# 20    Grig
# 21   Kiara

# %%
df1=pd.DataFrame(data=df,columns=["Name","Age","Salary"])
df1
# Out:
#       Name   Age   Salary
# 0      Tom  28.0  20000.0
# 1      Lee  31.0   3900.0
# 2     Dave  34.0   8000.0
# 3     Anik  26.0  66672.0
# 4    kamal  30.0      NaN
# 5     Geet   NaN  30007.0
# 6   Steven  43.0   8300.0
# 7      Ram  38.0  54666.0
# 8     hari  50.0  67666.0
# 9     yami   NaN   8888.0
# 10    Anik  26.0  66672.0
# 11   kamal  30.0  34344.0
# 12    Geet  22.0  30007.0
# 13  Steven  43.0   8300.0
# 14     Ram  38.0  54666.0
# 15    hari   NaN  67666.0
# 16    yami  27.0   8888.0
# 17     Lee  31.0      NaN
# 18  Andrew  34.0  34432.0
# 19   soham  32.0  34534.0
# 20    Grig  26.0  33451.0
# 21   Kiara  27.0      NaN

# %%
df[['Name','Age','Salary']].head(5)
# Out:
#     Name   Age   Salary
# 0    Tom  28.0  20000.0
# 1    Lee  31.0   3900.0
# 2   Dave  34.0   8000.0
# 3   Anik  26.0  66672.0
# 4  kamal  30.0      NaN

# %%
df[df["City"]=="newyork"]
# Out:
#     SNo  Name   Age     City  Country   Salary
# 8     9  hari  50.0  newyork  America  67666.0
# 9    11  yami   NaN  newyork  America   8888.0
# 15   17  hari   NaN  newyork  America  67666.0
# 16   18  yami  27.0  newyork  America   8888.0

# %%
df[(df["City"]=="newyork")&(df["Salary"]>50000)]
# Out:
#     SNo  Name   Age     City  Country   Salary
# 8     9  hari  50.0  newyork  America  67666.0
# 15   17  hari   NaN  newyork  America  67666.0

# %%
df[(df["Country"]=="Africa")&(df["Salary"]<65000)]
# Out:
#     SNo    Name   Age    City Country   Salary
# 18   20  Andrew  34.0   Congo  Africa  34432.0
# 19   21   soham  32.0  Angola  Africa  34534.0

# %%
df[df["Salary"].isna()]
# Out:
#     SNo   Name   Age     City  Country  Salary
# 4     5  kamal  30.0      NaN  America     NaN
# 17   19    Lee  31.0  Edmonto   Canada     NaN
# 21   23  Kiara  27.0   London   Europe     NaN

# %%
df[df["Salary"].notna()]
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df5=df.dropna(axis=0)
df5
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
df5.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64
