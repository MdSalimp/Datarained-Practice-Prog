# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title("histogram")
plt.show()

# %%
a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,bins=[0,20,40,60,80,100])
plt.title("histogram")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('student_marks.csv')
print(df)
df.columns
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
plt.hist(df['Maths'],bins=10)
plt.title('maths histogram')
plt.show()

# %%
plt.hist(df['English'],bins=10)
plt.title('English')
plt.show()

# %%
plt.boxplot(df['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2005f305790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2005f305df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2005f305340>],
#  'medians': [<matplotlib.lines.Line2D at 0x2005f313550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2005f3138e0>],
#  'means': []}

# %%
plt.boxplot(df['English'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2005f3785e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2005f378d00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2005f378250>],
#  'medians': [<matplotlib.lines.Line2D at 0x2005f383460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2005f3837f0>],
#  'means': []}

# %%
plt.violinplot(df['Maths'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2005f3d74f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2005f3d7460>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2005f3d7a30>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2005f3d7d60>}

# %%
plt.boxplot(df['English'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d461956640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d461956d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d4619562b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d4619624c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d461962850>],
#  'means': []}

# %%
plt.violinplot(df['Chemistry'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2005f4562e0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2005f456250>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2005f456820>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2005f456b50>}

# %%
x=np.array([3,6,44,12,67,45,55])
y=np.array([22,4,5,6,78,22,12])
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y)
plt.show()

# %%
a=np.array([3,6,44,12,67,45,55,23,5,96,78,96])
b=np.array([22,4,5,6,78,22,12,12,67,45,55,78])
plt.xlabel('a')
plt.ylabel('b')
plt.scatter(a,b)
plt.show()

# %%
x=df['Maths']
y=df['English']
plt.xlabel('Maths')
plt.ylabel('English')
plt.scatter(x,y)
plt.show()

# %%
x=df['Maths']
y=df['English']
plt.xlabel('Maths')
plt.ylabel('English')
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
x=['sun','mon','tue','wed','fri','sat','thu']
y=[5,6,7,8,9,10,11]
ax=sns.stripplot(x,y)
ax.set(xlabel='Days',ylabel="Amount_spend")
plt.title('My first graph')
plt.show()

# %%
ds=pd.read_csv('emptest.csv')
print(ds)
print(ds.head())
sns.violinplot(x='Salary',data=ds)
plt.show()
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.violinplot(x='Age',data=ds)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.stripplot(x='Salary',data=ds)
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.swarmplot(x='Salary',data=ds)
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.countplot(x='Salary',data=ds)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
sns.catplot(x='Salary',data=ds)

# %%
dsiris=pd.read_csv('iris.csv')
print(dsiris)
print(dsiris.head())
sns.set(style="whitegrid")
ax=sns.stripplot(x='class',y='sepal length',data=dsiris)
plt.title('Graph')
plt.show()
# Out:
#      sepal length  sepal width  petal length  petal width            class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
ax=sns.swarmplot(x='class',y='sepal length',data=dsiris)
plt.title('Graph')
plt.show()

# %%
ax=sns.stripplot(x='petal length',y='class',data=dsiris)
plt.title('Graph')
plt.show()

# %%
dsiris['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
sns.countplot(dsiris["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanicds=sns.load_dataset('titanic')
print(titanicds)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 1           1       1  female  38.00      1      0   71.2833        C   First
# 2           1       3  female  26.00      0      0    7.9250        S   Third
# 3           1       1  female  35.00      1      0   53.1000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 5           0       3    male    NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.00      0      0   51.8625        S   First
# 7           0       3    male   2.00      3      1   21.0750        S   Third
# 8           1       3  female  27.00      0      2   11.1333        S   Third
# 9           1       2  female  14.00      1      0   30.0708        C  Second
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
# 5       Third
# 6       First
# 7       Third
# 8       Third
# 9      Second
# 10      Third
# 11      First
# 12      Third
# 13      Third
# 14      Third
# 15     Second
# 16      Third
# 17     Second
# 18      Third
# 19      Third
# 20     Second
# 21     Second
# 22      Third
# 23      First
# 24      Third
# 25      Third
# 26      Third
# 27      First
# 28      Third
# 29      Third
# 30      First
# 31      First
# 32      Third
# 33     Second
# 34      First
# 35      First
# 36      Third
# 37      Third
# 38      Third
# 39      Third
# 40      Third
# 41     Second
# 42      Third
# 43     Second
# 44      Third
# 45      Third
# 46      Third
# 47      Third
# 48      Third
# 49      Third
# 50      Third
# 51      Third
# 52      First
# 53     Second
# 54      First
# 55      First
# 56     Second
# 57      Third
# 58     Second
# 59      Third
# 60      Third
# 61      First
# ...

# %%
titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds["class"])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='bar'
)

# %%
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='violin'
)

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
print(tips.head())
sns.violinplot(x = "total_bill", data=tips)
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot?

# %%
sns.histplot(data=tips,x='total_bill',bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['tip'],bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],bins=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],bins=50,kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,kind='ecdf',x='total_bill',col='time',hue='smoker')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip')

# %%
sns.rugplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.rugplot(data=tips,x='tip')
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(tips)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
sns.catplot(x='day',y='total_bill',hue='smoker',kind='box',data=tips)

# %%
iris=sns.load_dataset('iris')
print(iris)
sns.swarmplot(x='species',y='petal_length',data=iris)
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpgds=sns.load_dataset('mpg')
mpgds
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(data=mpgds,x='mpg',y='weight')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
sns.scatterplot(data=mpgds,x='horsepower',y='mpg')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.lineplot('horsepower','mpg',data=mpgds)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.relplot('horsepower','mpg',data=mpgds)

# %%
sns.boxplot(x='weight',data=mpgds)
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
sns.boxplot(x='displacement',data=mpgds)
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.rugplot(data=mpgds,x='weight',y='mpg')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='kde')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.swarmplot(data=mpgds,x='origin',y='mpg')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')

# %%
taxids=sns.load_dataset('taxis')
taxids
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
sns.scatterplot(x='fare',y='distance',data=taxids)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='distance'>

# %%
taxids['color'].value_counts()
# Out:
# yellow    5451
# green      982
# Name: color, dtype: int64

# %%
sns.countplot(x='color',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
taxids['payment'].value_counts()
# Out:
# credit card    4577
# cash           1812
# Name: payment, dtype: int64

# %%
sns.countplot(x='payment',data=taxids)
# Out:
# <AxesSubplot:xlabel='payment', ylabel='count'>

# %%
sns.stripplot(x='color',y='fare',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='fare'>

# %%
sns.boxplot(x='color',y='fare',hue='payment',data=taxids)
# Out:
# <AxesSubplot:xlabel='color', ylabel='fare'>

# %%
sns.lmplot('distance','fare',data=taxids,hue='payment')

# %%
sns.lmplot('distance','fare',data=taxids,hue='payment',col='color')

# %%
import seaborn as sns
flights=sns.load_dataset('flights')
flights=flights.pivot('month','year','passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax=sns.heatmap(flights)
ax
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>
